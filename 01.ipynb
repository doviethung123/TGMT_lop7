# %%
# !pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pillow in d:\thigiac\lib\site-packages (10.3.0)

# %%
from PIL import Image

# %%
dir = r'C:\Users\Admin\Documents\img'

# %%
image_path = dir + '/01.JPG'
print (image_path)
# Out:
# C:\Users\Admin\Documents\img/01.JPG

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1920x1200>

# %%
# In một số thông tin
# In Định dạng ảnh
print("Định dạnh ảnh: ", img01.format)
# Out:
# Định dạnh ảnh:  WEBP

# %%
print("Kích thước hình ảnh: ", img01.size)
# Out:
# Kích thước hình ảnh:  (1920, 1200)

# %%
#Lưu ảnh và chuyển đổi
new_img_01_path = dir + '/new_01.JPG'
new_img_png_01_path = dir + '/new_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_png_01_path)

# %%
# Đóng tập tin
img01.close()
