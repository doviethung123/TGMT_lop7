# %%
# !pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from PIL import Image
from imgtool import *

# %%
my_path = r'C:\Users\Admin\Documents\img\01.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1920x1200>

# %%
print(img.size)
# Out:
# (1920, 1200)

# %%
# Thay đổi kích thước
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
# Task: lưu ảnh
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
# Thay đổi kích thước
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Task: lưu ảnh
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=50x31>
